# %%
num1=  int ( input("Enter three numbers separated by space: "))
num2 = int ( input("Enter three numbers separated by space: "))
num3 = int ( input("Enter three numbers separated by space: "))

# %%
# Calculate sum
total = num1 + num2 + num3

print("The sum is:", total)
